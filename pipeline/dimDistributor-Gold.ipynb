# %%
# notebook parameters
id = "dimDistributor-Gold"

# %%
from common_function import readConfig, absPath, updatePipelineStatus,createHashKey
import pandas as pd
import os

# %%
config = readConfig(id)
config
# Out:
# ✓ Config loaded successfully: dimDistributor-Gold.json
# {'pipeline_id': 'dimDistributor-Gold',
#  'dependency': 'Revenues-Silver',
#  'target': {'pk': ['_sk_distributor'],
#   'format': 'parquet',
#   'name': 'dimDistributor',
#   'path': 'data\\03_gold\\',
#   'mode': 'overwrite'}}

# %%
# Read data 
path = os.path.join(absPath(), "data\\02_silver\\revenues")

df = pd.read_parquet(path, engine='fastparquet')

# %%
df = df[["distributor"]].drop_duplicates()

# %%
df = createHashKey(
    df=df,
    key_columns=['distributor'],
    hash_column='_sk_distributor'
)

# %%
df = df[[
        '_sk_distributor',
        'distributor'
        ]]

# %%
target_path = os.path.join(absPath(), config["target"]["path"],config["target"]["name"])

df.to_parquet(target_path, index=False)

# %%
updatePipelineStatus(id)
# Out:
# ✓ Updated pipeline status: dimDistributor-Gold - success
